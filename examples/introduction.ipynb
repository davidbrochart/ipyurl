# %% [markdown]
# # Introduction

# %% [markdown]
# You can launch the server with a different base URL and see it reflected in the `url` attribute of the widget:
#
# `jupyter lab --ServerApp.base_url=foo`

# %%
from ipyurl import Url

# %%
w = Url()
w

# %%
w.url

# %% [markdown]
# Or in an async environment (restart the kernel before execution the following cells):

# %%
from ipyurl import Url
from IPython.display import display
import asyncio

# %%
url = None
async def foo():
    global url
    w = Url()
    display(w)
    url = await w.get_url()
asyncio.ensure_future(foo())

# %%
url
